# %%
# import boto3

# dynamodb = boto3.resource("dynamodb")
# table = dynamodb.Table("toxicity_app")


import boto3

dynamodb = boto3.resource("dynamodb", region_name="us-east-1")
table = dynamodb.Table("toxicity_app")

# dynamodb = boto3.resource("dynamodb")
print("DynamoDB client works!")
table.put_item(Item={"timestamp": "12345", "msg": "Hello world"})
# Out:
# DynamoDB client works!
# {'ResponseMetadata': {'RequestId': 'T0TCF9K5VBPCAKUPAMME7QI4TRVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Mon, 17 Nov 2025 22:26:32 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'T0TCF9K5VBPCAKUPAMME7QI4TRVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}
